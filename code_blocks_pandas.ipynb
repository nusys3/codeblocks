# %%
import pandas as pd

# %%
df = pd.read_csv("../automation/tmp1.csv")

# %%
df
# Out:
#                  bssid  floor  timestamp
# 0    00:02:2d:50:e2:d9     -2         81
# 1    00:07:79:0a:90:80     -2         19
# 2    00:26:66:54:f8:88     -1          8
# 3    00:26:66:90:f4:a4     -2         88
# 4    00:26:66:90:f4:a4     -1          1
# 5    00:26:66:93:c7:90     -2         10
# 6    00:26:66:d7:ad:00     -1         10
# 7    00:30:0d:57:d4:b1     -1          7
# 8    00:30:0d:8d:20:00     -2          1
# 9    00:40:5a:e2:f8:05     -1          1
# 10   00:e0:4d:03:7c:30     -2          9
# 11   00:e0:4d:03:7c:30     -1        124
# 12   00:f6:63:79:7e:64     -1          2
# 13   00:f6:63:79:7e:65     -1          1
# 14   00:f6:63:97:16:72     -2          2
# 15   00:f6:63:97:16:74     -2          2
# 16   00:f6:63:bb:89:92     -2          2
# 17   00:f6:63:bb:89:93     -2          2
# 18   00:f6:63:bb:89:95     -2          2
# 19   02:3d:e8:6f:aa:f6     -2          3
# 20   02:3d:e8:6f:aa:f6     -1          1
# 21   02:e3:c7:09:9a:6e     -2         31
# ...
